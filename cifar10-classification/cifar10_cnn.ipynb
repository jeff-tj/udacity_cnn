# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=128, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=256, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        416
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 128)         32896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 256)         131328
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2, 2, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 702,826
# Trainable params: 702,826
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=256, epochs=50,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/50
#  - 7s - loss: 1.9417 - acc: 0.2910 - val_loss: 1.8419 - val_acc: 0.3072
#
# Epoch 00001: val_loss improved from inf to 1.84195, saving model to model.weights.best.hdf5
# Epoch 2/50
#  - 5s - loss: 1.5718 - acc: 0.4295 - val_loss: 1.4005 - val_acc: 0.4974
#
# Epoch 00002: val_loss improved from 1.84195 to 1.40051, saving model to model.weights.best.hdf5
# Epoch 3/50
#  - 5s - loss: 1.4026 - acc: 0.4922 - val_loss: 1.3029 - val_acc: 0.5318
#
# Epoch 00003: val_loss improved from 1.40051 to 1.30287, saving model to model.weights.best.hdf5
# Epoch 4/50
#  - 5s - loss: 1.2694 - acc: 0.5412 - val_loss: 1.1532 - val_acc: 0.5960
#
# Epoch 00004: val_loss improved from 1.30287 to 1.15318, saving model to model.weights.best.hdf5
# Epoch 5/50
#  - 5s - loss: 1.1692 - acc: 0.5799 - val_loss: 1.1154 - val_acc: 0.6040
#
# Epoch 00005: val_loss improved from 1.15318 to 1.11539, saving model to model.weights.best.hdf5
# Epoch 6/50
#  - 5s - loss: 1.0892 - acc: 0.6086 - val_loss: 1.0290 - val_acc: 0.6300
#
# Epoch 00006: val_loss improved from 1.11539 to 1.02900, saving model to model.weights.best.hdf5
# Epoch 7/50
#  - 5s - loss: 1.0176 - acc: 0.6367 - val_loss: 0.9764 - val_acc: 0.6618
#
# Epoch 00007: val_loss improved from 1.02900 to 0.97635, saving model to model.weights.best.hdf5
# Epoch 8/50
#  - 5s - loss: 0.9571 - acc: 0.6582 - val_loss: 0.9042 - val_acc: 0.6816
#
# Epoch 00008: val_loss improved from 0.97635 to 0.90422, saving model to model.weights.best.hdf5
# Epoch 9/50
#  - 5s - loss: 0.9029 - acc: 0.6800 - val_loss: 0.8864 - val_acc: 0.6864
#
# Epoch 00009: val_loss improved from 0.90422 to 0.88636, saving model to model.weights.best.hdf5
# Epoch 10/50
#  - 5s - loss: 0.8531 - acc: 0.6968 - val_loss: 0.8845 - val_acc: 0.6880
#
# Epoch 00010: val_loss improved from 0.88636 to 0.88447, saving model to model.weights.best.hdf5
# Epoch 11/50
#  - 5s - loss: 0.8087 - acc: 0.7146 - val_loss: 0.9131 - val_acc: 0.6826
#
# Epoch 00011: val_loss did not improve from 0.88447
# Epoch 12/50
#  - 5s - loss: 0.7664 - acc: 0.7284 - val_loss: 0.7984 - val_acc: 0.7194
#
# Epoch 00012: val_loss improved from 0.88447 to 0.79843, saving model to model.weights.best.hdf5
# Epoch 13/50
#  - 5s - loss: 0.7279 - acc: 0.7417 - val_loss: 0.8104 - val_acc: 0.7186
#
# Epoch 00013: val_loss did not improve from 0.79843
# Epoch 14/50
#  - 5s - loss: 0.6901 - acc: 0.7567 - val_loss: 0.8117 - val_acc: 0.7198
#
# Epoch 00014: val_loss did not improve from 0.79843
# Epoch 15/50
#  - 5s - loss: 0.6648 - acc: 0.7646 - val_loss: 0.9149 - val_acc: 0.6916
#
# Epoch 00015: val_loss did not improve from 0.79843
# Epoch 16/50
#  - 5s - loss: 0.6310 - acc: 0.7758 - val_loss: 0.8060 - val_acc: 0.7204
#
# Epoch 00016: val_loss did not improve from 0.79843
# Epoch 17/50
#  - 5s - loss: 0.5959 - acc: 0.7878 - val_loss: 0.7404 - val_acc: 0.7468
#
# Epoch 00017: val_loss improved from 0.79843 to 0.74039, saving model to model.weights.best.hdf5
# Epoch 18/50
#  - 5s - loss: 0.5703 - acc: 0.7994 - val_loss: 0.7889 - val_acc: 0.7340
#
# Epoch 00018: val_loss did not improve from 0.74039
# Epoch 19/50
#  - 5s - loss: 0.5442 - acc: 0.8062 - val_loss: 0.8756 - val_acc: 0.7072
#
# Epoch 00019: val_loss did not improve from 0.74039
# Epoch 20/50
#  - 5s - loss: 0.5150 - acc: 0.8166 - val_loss: 0.8258 - val_acc: 0.7368
#
# Epoch 00020: val_loss did not improve from 0.74039
# Epoch 21/50
#  - 5s - loss: 0.4885 - acc: 0.8256 - val_loss: 0.8053 - val_acc: 0.7338
#
# Epoch 00021: val_loss did not improve from 0.74039
# Epoch 22/50
#  - 5s - loss: 0.4707 - acc: 0.8321 - val_loss: 0.7608 - val_acc: 0.7548
#
# Epoch 00022: val_loss did not improve from 0.74039
# Epoch 23/50
#  - 6s - loss: 0.4480 - acc: 0.8415 - val_loss: 0.8378 - val_acc: 0.7258
#
# Epoch 00023: val_loss did not improve from 0.74039
# Epoch 24/50
#  - 5s - loss: 0.4296 - acc: 0.8475 - val_loss: 0.7579 - val_acc: 0.7540
#
# Epoch 00024: val_loss did not improve from 0.74039
# Epoch 25/50
#  - 5s - loss: 0.4129 - acc: 0.8522 - val_loss: 0.7749 - val_acc: 0.7482
#
# Epoch 00025: val_loss did not improve from 0.74039
# Epoch 26/50
#  - 5s - loss: 0.3887 - acc: 0.8632 - val_loss: 0.8090 - val_acc: 0.7378
#
# Epoch 00026: val_loss did not improve from 0.74039
# Epoch 27/50
#  - 5s - loss: 0.3748 - acc: 0.8648 - val_loss: 0.7777 - val_acc: 0.7590
#
# Epoch 00027: val_loss did not improve from 0.74039
# Epoch 28/50
#  - 5s - loss: 0.3543 - acc: 0.8731 - val_loss: 0.7677 - val_acc: 0.7560
#
# Epoch 00028: val_loss did not improve from 0.74039
# Epoch 29/50
#  - 5s - loss: 0.3450 - acc: 0.8772 - val_loss: 0.8532 - val_acc: 0.7442
#
# Epoch 00029: val_loss did not improve from 0.74039
# Epoch 30/50
#  - 5s - loss: 0.3278 - acc: 0.8827 - val_loss: 0.9286 - val_acc: 0.7180
#
# Epoch 00030: val_loss did not improve from 0.74039
# Epoch 31/50
#  - 5s - loss: 0.3173 - acc: 0.8866 - val_loss: 0.8307 - val_acc: 0.7606
#
# Epoch 00031: val_loss did not improve from 0.74039
# Epoch 32/50
#  - 5s - loss: 0.3039 - acc: 0.8918 - val_loss: 0.8315 - val_acc: 0.7584
#
# Epoch 00032: val_loss did not improve from 0.74039
# Epoch 33/50
#  - 5s - loss: 0.2920 - acc: 0.8951 - val_loss: 0.8562 - val_acc: 0.7590
#
# Epoch 00033: val_loss did not improve from 0.74039
# Epoch 34/50
#  - 5s - loss: 0.2896 - acc: 0.8976 - val_loss: 0.9329 - val_acc: 0.7422
#
# Epoch 00034: val_loss did not improve from 0.74039
# Epoch 35/50
#  - 5s - loss: 0.2726 - acc: 0.9024 - val_loss: 0.8435 - val_acc: 0.7506
#
# Epoch 00035: val_loss did not improve from 0.74039
# Epoch 36/50
#  - 5s - loss: 0.2663 - acc: 0.9076 - val_loss: 0.8808 - val_acc: 0.7546
#
# Epoch 00036: val_loss did not improve from 0.74039
# Epoch 37/50
#  - 5s - loss: 0.2532 - acc: 0.9092 - val_loss: 0.9584 - val_acc: 0.7596
#
# Epoch 00037: val_loss did not improve from 0.74039
# Epoch 38/50
#  - 5s - loss: 0.2541 - acc: 0.9096 - val_loss: 0.9225 - val_acc: 0.7624
#
# Epoch 00038: val_loss did not improve from 0.74039
# Epoch 39/50
#  - 5s - loss: 0.2364 - acc: 0.9167 - val_loss: 0.9909 - val_acc: 0.7280
#
# Epoch 00039: val_loss did not improve from 0.74039
# Epoch 40/50
#  - 5s - loss: 0.2354 - acc: 0.9171 - val_loss: 0.9347 - val_acc: 0.7604
#
# Epoch 00040: val_loss did not improve from 0.74039
# Epoch 41/50
#  - 5s - loss: 0.2285 - acc: 0.9177 - val_loss: 0.9812 - val_acc: 0.7614
#
# Epoch 00041: val_loss did not improve from 0.74039
# Epoch 42/50
#  - 5s - loss: 0.2235 - acc: 0.9210 - val_loss: 1.0618 - val_acc: 0.7448
#
# Epoch 00042: val_loss did not improve from 0.74039
# Epoch 43/50
#  - 5s - loss: 0.2171 - acc: 0.9237 - val_loss: 0.9788 - val_acc: 0.7484
#
# Epoch 00043: val_loss did not improve from 0.74039
# Epoch 44/50
#  - 5s - loss: 0.2140 - acc: 0.9246 - val_loss: 1.0460 - val_acc: 0.7562
#
# Epoch 00044: val_loss did not improve from 0.74039
# Epoch 45/50
#  - 5s - loss: 0.2056 - acc: 0.9288 - val_loss: 1.0406 - val_acc: 0.7492
#
# Epoch 00045: val_loss did not improve from 0.74039
# Epoch 46/50
#  - 5s - loss: 0.2038 - acc: 0.9285 - val_loss: 0.9273 - val_acc: 0.7498
#
# Epoch 00046: val_loss did not improve from 0.74039
# Epoch 47/50
#  - 5s - loss: 0.1929 - acc: 0.9319 - val_loss: 0.9957 - val_acc: 0.7622
#
# Epoch 00047: val_loss did not improve from 0.74039
# Epoch 48/50
#  - 5s - loss: 0.1945 - acc: 0.9308 - val_loss: 1.0091 - val_acc: 0.7546
#
# Epoch 00048: val_loss did not improve from 0.74039
# Epoch 49/50
#  - 5s - loss: 0.1935 - acc: 0.9325 - val_loss: 1.0415 - val_acc: 0.7596
#
# Epoch 00049: val_loss did not improve from 0.74039
# Epoch 50/50
#  - 5s - loss: 0.1889 - acc: 0.9348 - val_loss: 1.1637 - val_acc: 0.7444
#
# Epoch 00050: val_loss did not improve from 0.74039

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.7315

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
